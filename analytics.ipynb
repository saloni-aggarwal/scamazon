# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
pd.set_option('display.max_columns', None)

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
file = 'amazon-reviews-withloc-withimg.csv'
df = pd.read_csv(file)
df.head()
# Out:
#                                                 name                  asins  \
# 0  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 1  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 2  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 3  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 4  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
#
#                                           categories primaryCategories  \
# 0  AA,AAA,Health,Electronics,Health & Household,C...   Health & Beauty
# 1  AA,AAA,Health,Electronics,Health & Household,C...   Health & Beauty
# 2  AA,AAA,Health,Electronics,Health & Household,C...   Health & Beauty
# 3  AA,AAA,Health,Electronics,Health & Household,C...   Health & Beauty
# 4  AA,AAA,Health,Electronics,Health & Household,C...   Health & Beauty
#
#                                            imageURLs  manufacturer  \
# ...

# %%
df.groupby('name').count()
# Out:
#                                                     asins  categories  \
# name
# All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi, ...   2370        2370
# All-New Kindle Oasis E-reader - 7 High-Resoluti...     22          22
# AmazonBasics 15.6-Inch Laptop and Tablet Bag           21          21
# AmazonBasics AAA Performance Alkaline Batteries...   8343        8343
# AmazonBasics Backpack for Laptops up to 17-inches      25          25
# AmazonBasics Bluetooth Keyboard for Android Dev...      6           6
# AmazonBasics Double-Door Folding Metal Dog Crat...      2           2
# AmazonBasics External Hard Drive Case                   6           6
# AmazonBasics Nespresso Pod Storage Drawer - 50 ...      1           1
# AmazonBasics Silicone Hot Handle Cover/Holder -...      1           1
# Cat Litter Box Covered Tray Kitten Extra Large ...      2           2
# Certified Refurbished Amazon Echo                       7           7
# ...

# %%
df2= df.groupby('name').head(20)

# %%
from sklearn.utils import shuffle
df_rand = shuffle(df2, random_state=0)

# %%
df_rand.name.unique()
# Out:
# array(['AmazonBasics Backpack for Laptops up to 17-inches',
#        'AmazonBasics External Hard Drive Case',
#        'AmazonBasics AAA Performance Alkaline Batteries (36 Count)',
#        'AmazonBasics 15.6-Inch Laptop and Tablet Bag',
#        'Fire TV Stick Streaming Media Player Pair Kit',
#        'All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi, 16 GB - Includes Special Offers, Black',
#        'AmazonBasics Bluetooth Keyboard for Android Devices - Black',
#        'AmazonBasics Nespresso Pod Storage Drawer - 50 Capsule Capacity',
#        'Certified Refurbished Amazon Echo',
#        'All-New Kindle Oasis E-reader - 7 High-Resolution Display (300 ppi), Waterproof, Built-In Audible, 8 GB, Wi-Fi - Includes Special Offers',
#        'Cat Litter Box Covered Tray Kitten Extra Large Enclosed Hooded Hidden Toilet',
#        'AmazonBasics Double-Door Folding Metal Dog Crate - Medium (36x23x25 Inches)',
#        'AmazonBasics Silicone Hot Handle Cover/Holder - Red',
# ...

# %%
from faker import Faker
fake = Faker()

# %%
Faker.seed(0)
zipcode = []
for _ in range(len(df_rand)):
    zipcode.append(fake.zipcode())

# %%
len(zipcode)
# Out:
# 142

# %%
#df_rand['zipcode'] = zipcode
# Out:
# <ipython-input-33-1d88ca67c8db>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rand['zipcode'] = zipcode

# %%
df_rand
# Out:
#                                                     name  \
# 8368   AmazonBasics Backpack for Laptops up to 17-inches
# 8397               AmazonBasics External Hard Drive Case
# 16     AmazonBasics AAA Performance Alkaline Batterie...
# 8384        AmazonBasics 15.6-Inch Laptop and Tablet Bag
# 8345       Fire TV Stick Streaming Media Player Pair Kit
# ...                                                  ...
# 9      AmazonBasics AAA Performance Alkaline Batterie...
# 8432   All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 8395        AmazonBasics 15.6-Inch Laptop and Tablet Bag
# 10796  All-New Kindle Oasis E-reader - 7 High-Resolut...
# 8370   AmazonBasics Backpack for Laptops up to 17-inches
#
#                        asins  \
# 8368   B00EEBS9O0,B01CHQHIJK
# 8397   B00F5CKWBA,B00KPQCWAU
# 16     B00QWO9P0O,B00LH3DMUO
# 8384              B00DUGZFWY
# 8345              B00ZV9RDKK
# ...                      ...
# 9      B00QWO9P0O,B00LH3DMUO
# 8432   B018SZT3BK,B01AHB9CN2
# ...

# %%
df_rand.groupby('name').count()
# Out:
#                                                     asins  categories  \
# name
# All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi, ...     20          20
# All-New Kindle Oasis E-reader - 7 High-Resoluti...     20          20
# AmazonBasics 15.6-Inch Laptop and Tablet Bag           20          20
# AmazonBasics AAA Performance Alkaline Batteries...     20          20
# AmazonBasics Backpack for Laptops up to 17-inches      20          20
# AmazonBasics Bluetooth Keyboard for Android Dev...      6           6
# AmazonBasics Double-Door Folding Metal Dog Crat...      2           2
# AmazonBasics External Hard Drive Case                   6           6
# AmazonBasics Nespresso Pod Storage Drawer - 50 ...      1           1
# AmazonBasics Silicone Hot Handle Cover/Holder -...      1           1
# Cat Litter Box Covered Tray Kitten Extra Large ...      2           2
# Certified Refurbished Amazon Echo                       7           7
# ...

# %%
df_rand.loc[df_rand['name'] == 'AmazonBasics AAA Performance Alkaline Batteries (36 Count)', 'zipcode'] = 14623
df_rand.loc[df_rand['name'] == 'AmazonBasics AAA Performance Alkaline Batteries (36 Count)', 'latitude'] = 43.1566
df_rand.loc[df_rand['name'] == 'AmazonBasics AAA Performance Alkaline Batteries (36 Count)', 'longitude'] = -77.6088
# Out:
# C:\Users\ketak\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df_rand.loc[df_rand['name'] == 'AmazonBasics AAA Performance Alkaline Batteries (36 Count)']
# Out:
#                                                  name                  asins  \
# 16  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 7   AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 8   AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 18  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 2   AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 10  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 13  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 15  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 3   AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 6   AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 12  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# ...

# %%
df_rand.loc[df_rand.name == 'Cat Litter Box Covered Tray Kitten Extra Large Enclosed Hooded Hidden Toilet']
# Out:
#                                                    name  \
# 8412  Cat Litter Box Covered Tray Kitten Extra Large...
# 8413  Cat Litter Box Covered Tray Kitten Extra Large...
#
#                       asins  \
# 8412  B074MCBG25,B075357QFB
# 8413  B074MCBG25,B075357QFB
#
#                                              categories  \
# 8412  Standard Litter Boxes,Litter Boxes,Cat Supplie...
# 8413  Standard Litter Boxes,Litter Boxes,Cat Supplie...
#
#            primaryCategories  \
# 8412  Animals & Pet Supplies
# 8413  Animals & Pet Supplies
#
#                                               imageURLs  manufacturer  \
# 8412  https://m.media-amazon.com/images/I/718V7h1O6u...  AmazonBasics
# 8413  https://m.media-amazon.com/images/I/718V7h1O6u...  AmazonBasics
#
#                   reviews.date reviews.doRecommend reviews.numHelpful  \
# 8412  2018-05-16T00:00:00.000Z         Unavailable        Unavailable
# 8413  2018-11-21T00:00:00.000Z         Unavailable        Unavailable
#
# ...

# %%
i = 8419
df_rand.at[i, 'zipcode'] = 7602
df_rand.at[i, 'latitude'] = 7602
df_rand.at[i, 'longitude'] = 7602

# %%
df_rand.head()
# Out:
#                                                    name  \
# 8368  AmazonBasics Backpack for Laptops up to 17-inches
# 8397              AmazonBasics External Hard Drive Case
# 16    AmazonBasics AAA Performance Alkaline Batterie...
# 8384       AmazonBasics 15.6-Inch Laptop and Tablet Bag
# 8345      Fire TV Stick Streaming Media Player Pair Kit
#
#                       asins  \
# 8368  B00EEBS9O0,B01CHQHIJK
# 8397  B00F5CKWBA,B00KPQCWAU
# 16    B00QWO9P0O,B00LH3DMUO
# 8384             B00DUGZFWY
# 8345             B00ZV9RDKK
#
#                                              categories primaryCategories  \
# 8368  Portable Computer Accessories,Bags, Cases & Sl...       Electronics
# 8397  Electronics Features,Drives, Storage & Blank M...       Electronics
# 16    AA,AAA,Health,Electronics,Health & Household,C...   Health & Beauty
# 8384  Bags, Cases & Sleeves,Computers & Accessories,...       Electronics
# 8345  Electronics,TVs Entertainment,Featured Brands,...       Electronics
#
# ...

# %%
#df_rand.to_csv('Amazon-Reviews-tiny-with-loc-zip-shuffled-v2.csv', index = False)

# %%
df_rand
# Out:
#                                                     name  \
# 8368   AmazonBasics Backpack for Laptops up to 17-inches
# 8397               AmazonBasics External Hard Drive Case
# 16     AmazonBasics AAA Performance Alkaline Batterie...
# 8384        AmazonBasics 15.6-Inch Laptop and Tablet Bag
# 8345       Fire TV Stick Streaming Media Player Pair Kit
# ...                                                  ...
# 9      AmazonBasics AAA Performance Alkaline Batterie...
# 8432   All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 8395        AmazonBasics 15.6-Inch Laptop and Tablet Bag
# 10796  All-New Kindle Oasis E-reader - 7 High-Resolut...
# 8370   AmazonBasics Backpack for Laptops up to 17-inches
#
#                        asins  \
# 8368   B00EEBS9O0,B01CHQHIJK
# 8397   B00F5CKWBA,B00KPQCWAU
# 16     B00QWO9P0O,B00LH3DMUO
# 8384              B00DUGZFWY
# 8345              B00ZV9RDKK
# ...                      ...
# 9      B00QWO9P0O,B00LH3DMUO
# 8432   B018SZT3BK,B01AHB9CN2
# ...
